# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Load the pre-trained VGG16 model without the top (fully connected) layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers for skin disease classification
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(num_classes, activation='softmax')  # Replace num_classes with the number of skin disease classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Save the model to a .h5 file
model.save('pretrained_model.h5')

# %% [markdown]
# import tensorflow as tf
# from tensorflow.keras.applications import VGG16
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Flatten
#
# # Load the pre-trained VGG16 model without the top (fully connected) layers
# base_model = VGG16(weights='path/to/pretrained_vgg16_weights.h5', include_top=False, input_shape=(224, 224, 3))
#
# # Freeze the base model layers
# for layer in base_model.layers:
#     layer.trainable = False
#
# # Add custom top layers for skin disease classification
# model = Sequential([
#     base_model,
#     Flatten(),
#     Dense(512, activation='relu'),
#     Dense(256, activation='relu'),
#     Dense(num_classes, activation='softmax')  # Replace num_classes with the number of skin disease classes
# ])
#
# # Compile the model
# model.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])
#
# # Print model summary
# model.summary()
#
# # Save the model to a .h5 file
# model.save('path/to/save/pretrained_model.h5')

# %% [markdown]
# import tensorflow as tf
# from tensorflow.keras.preprocessing import image
# import numpy as np
#
# # Load the pre-trained skin disease classification model
# model = tf.keras.models.load_model('path/to/your/pretrained_model.h5')
#
# # Define the skin disease classes (if known)
# # Replace these with the actual class names used in your model
# class_names = ['class_1', 'class_2', 'class_3', ...]
#
# def load_and_preprocess_image(image_path):
#     # Load the image from file and resize it to the required input size of the model
#     img = image.load_img(image_path, target_size=(224, 224))
#     img_array = image.img_to_array(img)
#     img_array = np.expand_dims(img_array, axis=0)
#     return img_array
#
# def classify_skin_disease(image_path):
#     # Load and preprocess the image
#     img_array = load_and_preprocess_image(image_path)
#
#     # Make predictions using the loaded model
#     predictions = model.predict(img_array)
#     predicted_class_index = np.argmax(predictions[0])
#     predicted_class = class_names[predicted_class_index]
#
#     return predicted_class, predictions[0]
#
# if __name__ == '__main__':
#     # Example usage: classify a skin disease image
#     image_path = 'path/to/your/test_image.jpg'
#     predicted_class, confidence_scores = classify_skin_disease(image_path)
#     print(f'Predicted class: {predicted_class}')
#     print('Confidence scores:', confidence_scores)

# %% [markdown]
# import tensorflow as tf
# from tensorflow.keras import layers
#
# # Define the model
# model = tf.keras.Sequential([
#     layers.Dense(64, activation='relu', input_shape=(784,)),
#     layers.Dense(10, activation='softmax')
# ])
#
# # Compile the model
# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])
#
# # Print model summary
# model.summary()

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Load the pre-trained VGG16 model without the top (fully connected) layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers for skin disease classification
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(num_classes, activation='softmax')  # Replace num_classes with the number of skin disease classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Save the model to a .h5 file
model.save('pretrained_model.h5')

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Load the pre-trained VGG16 model without the top (fully connected) layers
base_model = VGG16(weights='/tensorflow/pretrained_vgg16_weights.h5', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers for skin disease classification
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(num_classes, activation='softmax')  # Replace num_classes with the number of skin disease classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Save the model to a .h5 file
model.save('/tensoflow/pretrained_model.h5')

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the pre-trained skin disease classification model
model = tf.keras.models.load_model('/tensorflow/pretrained_model.h5')

# Define the skin disease classes (if known)
# Replace these with the actual class names used in your model
class_names = ['class_1', 'class_2', 'class_3', ...]

def load_and_preprocess_image(image_path):
    # Load the image from file and resize it to the required input size of the model
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

def classify_skin_disease(image_path):
    # Load and preprocess the image
    img_array = load_and_preprocess_image(image_path)

    # Make predictions using the loaded model
    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions[0])
    predicted_class = class_names[predicted_class_index]

    return predicted_class, predictions[0]

if __name__ == '__main__':
    # Example usage: classify a skin disease image
    image_path = '/media/test_image.jpg'
    predicted_class, confidence_scores = classify_skin_disease(image_path)
    print(f'Predicted class: {predicted_class}')
    print('Confidence scores:', confidence_scores)
